# %% [markdown]
# <b>Data Cleansing Project<b>
# Big_Cities_Health_Data_Inventory.csv
#
# <b>SUMMARY<b>
# This dataset illustrates health status of 26 of the nation’s largest and most urban cities as captured by 34 health (and six demographics-related) indicators. These indicators represent some of the leading causes of morbidity and mortality in the United States and leading priorities of national, state, and local health agencies. Public health data were captured in nine overarching categories: HIV/AIDS, cancer, nutrition/physical activity/obesity, food safety, infectious disease, maternal and child health, tobacco, injury/violence, and behavioral health/substance abuse.
#
#     Indicator Category            13512 non-null object
# Indicator                     13512 non-null object
# Year                          13512 non-null object
# Gender                        13512 non-null object
# Race/ Ethnicity               13512 non-null object
# Value                         13499 non-null float64
# Place                         13512 non-null object
# BCHC Requested Methodology    13004 non-null object
# Source                        11222 non-null object
# Methods                       4232 non-null object
# Notes                         3541 non-null object

# %%
import pandas as pd
import numpy as np

# %%
health_data = pd.read_csv("C:/Users/sgosai/Desktop/Personal/Python/Data Cleansing/Big_Cities_Health_Data_Inventory.csv")
pd.set_option('display.max_colwidth', -1)

# %%
health_data.head()
# Out:
#   Indicator Category  \
# 0  HIV/AIDS
# 1  HIV/AIDS
# 2  HIV/AIDS
# 3  Cancer
# 4  Cancer
#
#                                                                Indicator  \
# 0  AIDS Diagnoses Rate (Per 100,000 people)
# 1  AIDS Diagnoses Rate (Per 100,000 people)
# 2  AIDS Diagnoses Rate (Per 100,000 people)
# 3  All Types of Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)
# 4  All Types of Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)
#
#    Year  Gender Race/ Ethnicity  Value                        Place  \
# 0  2013  Both    All             30.4   Atlanta (Fulton County), GA
# 1  2012  Both    All             39.6   Atlanta (Fulton County), GA
# 2  2011  Both    All             41.7   Atlanta (Fulton County), GA
# 3  2013  Male    All             195.8  Atlanta (Fulton County), GA
# 4  2013  Female  All             135.5  Atlanta (Fulton County), GA
#
# ...

# %%
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13512 entries, 0 to 13511
# Data columns (total 11 columns):
# Indicator Category            13512 non-null object
# Indicator                     13512 non-null object
# Year                          13512 non-null object
# Gender                        13512 non-null object
# Race/ Ethnicity               13512 non-null object
# Value                         13499 non-null float64
# Place                         13512 non-null object
# BCHC Requested Methodology    13004 non-null object
# Source                        11222 non-null object
# Methods                       4232 non-null object
# Notes                         3541 non-null object
# dtypes: float64(1), object(10)
# memory usage: 1.1+ MB

# %% [markdown]
# 11 columns and most of them are stored as objects.

# %%
health_data.describe(include ='all')
# Out:
#        Indicator Category  \
# count   13512
# unique  11
# top     HIV/AIDS
# freq    2177
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN
#
#                                                      Indicator   Year Gender  \
# count   13512                                                   13512  13512
# unique  44                                                      13     3
# top     Persons Living with HIV/AIDS Rate (Per 100,000 people)  2012   Both
# freq    623                                                     3950   9409
# mean    NaN                                                     NaN    NaN
# std     NaN                                                     NaN    NaN
# min     NaN                                                     NaN    NaN
# 25%     NaN                                                     NaN    NaN
# 50%     NaN                                                     NaN    NaN
# ...

# %%
health_data.head()
# Out:
#   Indicator Category  \
# 0  HIV/AIDS
# 1  HIV/AIDS
# 2  HIV/AIDS
# 3  Cancer
# 4  Cancer
#
#                                                                Indicator  \
# 0  AIDS Diagnoses Rate (Per 100,000 people)
# 1  AIDS Diagnoses Rate (Per 100,000 people)
# 2  AIDS Diagnoses Rate (Per 100,000 people)
# 3  All Types of Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)
# 4  All Types of Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)
#
#    Year  Gender Race/ Ethnicity  Value                        Place  \
# 0  2013  Both    All             30.4   Atlanta (Fulton County), GA
# 1  2012  Both    All             39.6   Atlanta (Fulton County), GA
# 2  2011  Both    All             41.7   Atlanta (Fulton County), GA
# 3  2013  Male    All             195.8  Atlanta (Fulton County), GA
# 4  2013  Female  All             135.5  Atlanta (Fulton County), GA
#
# ...

# %%
health_data.rename({"Indicator Category": "Indicator_Category"}, axis = 1, inplace = True)

# %%
health_data.head()
# Out:
#   Indicator_Category  \
# 0  HIV/AIDS
# 1  HIV/AIDS
# 2  HIV/AIDS
# 3  Cancer
# 4  Cancer
#
#                                                                Indicator  \
# 0  AIDS Diagnoses Rate (Per 100,000 people)
# 1  AIDS Diagnoses Rate (Per 100,000 people)
# 2  AIDS Diagnoses Rate (Per 100,000 people)
# 3  All Types of Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)
# 4  All Types of Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)
#
#    Year  Gender Race/ Ethnicity  Value                        Place  \
# 0  2013  Both    All             30.4   Atlanta (Fulton County), GA
# 1  2012  Both    All             39.6   Atlanta (Fulton County), GA
# 2  2011  Both    All             41.7   Atlanta (Fulton County), GA
# 3  2013  Male    All             195.8  Atlanta (Fulton County), GA
# 4  2013  Female  All             135.5  Atlanta (Fulton County), GA
#
# ...

# %%
health_data["Indicator_Category"].value_counts()
# Out:
# HIV/AIDS                                    2177
# Injury and Violence                         1916
# Nutrition, Physical Activity, & Obesity     1841
# Infectious Disease                          1486
# Cancer                                      1432
# Maternal and Child Health                   1323
# Behavioral Health/Substance Abuse           983
# Food Safety                                 874
# Life Expectancy and Death Rate (Overall)    544
# Demographics                                504
# Tobacco                                     432
# Name: Indicator_Category, dtype: int64

# %%
health_data["Year"].value_counts().sort_index()
# Out:
# 2003-2012    2
# 2003-2013    1
# 2004-2013    1
# 2007-2012    3
# 2008-2012    7
# 2010         1357
# 2011         3501
# 2011-2012    6
# 2011-2013    1
# 2012         3950
# 2013         3657
# 2014         1020
# 2015         6
# Name: Year, dtype: int64

# %%
health_data[health_data["Year"]== '2003-2013' ]
# Out:
#                             Indicator_Category  \
# 5526  Life Expectancy and Death Rate (Overall)
#
#                              Indicator       Year Gender Race/ Ethnicity  \
# 5526  Life Expectancy at Birth (Years)  2003-2013  Both   All
#
#       Value                          Place  \
# 5526  80.0   Miami (Miami-Dade County), FL
#
#                                           BCHC Requested Methodology  \
# 5526  Three most recent years as available; Life expectancy at birth
#
#                                                                  Source  \
# 5526  VCU Center on Society and Health (www.societyhealth.vcu.edu/maps)
#
#      Methods                              Notes
# 5526  NaN     Miami Dade County, not just Miami

# %%
health_data.loc[health_data.Year.str.contains("-"),"Year"] = "2012"

# %%
health_data.iloc[5526,:]
# Out:
# Indicator_Category            Life Expectancy and Death Rate (Overall)
# Indicator                     Life Expectancy at Birth (Years)
# Year                          2012
# Gender                        Both
# Race/ Ethnicity               All
# Value                         80
# Place                         Miami (Miami-Dade County), FL
# BCHC Requested Methodology    Three most recent years as available; Life expectancy at birth
# Source                        VCU Center on Society and Health (www.societyhealth.vcu.edu/maps)
# Methods                       NaN
# Notes                         Miami Dade County, not just Miami
# Name: 5526, dtype: object

# %%
health_data["Year"].astype(int)
# Out:
# 0        2013
# 1        2012
# 2        2011
# 3        2013
# 4        2013
#          ...
# 13507    2013
# 13508    2013
# 13509    2014
# 13510    2014
# 13511    2014
# Name: Year, Length: 13512, dtype: int32

# %%
health_data.dtypes
health_data.astype({'Year': 'int32'}).dtypes
# Out:
# Indicator_Category            object
# Indicator                     object
# Year                          int32
# Gender                        object
# Race/ Ethnicity               object
# Value                         float64
# Place                         object
# BCHC Requested Methodology    object
# Source                        object
# Methods                       object
# Notes                         object
# dtype: object

# %%
#place
health_data["Place"].value_counts().sort_index()
# Out:
# Atlanta (Fulton County), GA        313
# Baltimore, MD                      221
# Boston, MA                         465
# Chicago, IL                        576
# Cleveland, OH                      295
# Dallas, TX                         124
# Denver, CO                         649
# Detroit, MI                        289
# Fort Worth (Tarrant County), TX    332
# Houston, TX                        410
# Kansas City, MO                    383
# Las Vegas (Clark County), NV       594
# Long Beach, CA                     667
# Los Angeles, CA                    582
# Miami (Miami-Dade County), FL      707
# Minneapolis, MN                    424
# New York, NY                       651
# Oakland, CA                        250
# Philadelphia, PA                   558
# Phoenix, AZ                        772
# Portland (Multnomah County), OR    623
# Sacramento, CA                     367
# San Antonio, TX                    498
# San Diego County, CA               447
# ...

# %%
#checing for nulls
health_data["Place"].isnull().sum()
# Out:
# 0

# %%
#Splitting into new dataframe called NEW
new = health_data["Place"].str.split(",", n = 1, expand =True)

# %%
new.head()
# Out:
#                          0    1
# 0  Atlanta (Fulton County)   GA
# 1  Atlanta (Fulton County)   GA
# 2  Atlanta (Fulton County)   GA
# 3  Atlanta (Fulton County)   GA
# 4  Atlanta (Fulton County)   GA

# %%
health_data["City"] = new[0]

# %%
health_data["State"] = new[1]

# %%
health_data.head()
# Out:
#   Indicator_Category  \
# 0  HIV/AIDS
# 1  HIV/AIDS
# 2  HIV/AIDS
# 3  Cancer
# 4  Cancer
#
#                                                                Indicator  \
# 0  AIDS Diagnoses Rate (Per 100,000 people)
# 1  AIDS Diagnoses Rate (Per 100,000 people)
# 2  AIDS Diagnoses Rate (Per 100,000 people)
# 3  All Types of Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)
# 4  All Types of Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)
#
#    Year  Gender Race/ Ethnicity  Value                        Place  \
# 0  2013  Both    All             30.4   Atlanta (Fulton County), GA
# 1  2012  Both    All             39.6   Atlanta (Fulton County), GA
# 2  2011  Both    All             41.7   Atlanta (Fulton County), GA
# 3  2013  Male    All             195.8  Atlanta (Fulton County), GA
# 4  2013  Female  All             135.5  Atlanta (Fulton County), GA
#
# ...

# %%
x = health_data.groupby(["State", "Indicator_Category"])["Indicator_Category"].count().sort_values(ascending=False)

# %%
y = x.reset_index(name='count')

# %%
y.head(20)
# Out:
#    State                        Indicator_Category  count
# 0    CA   HIV/AIDS                                  541
# 1    CA   Injury and Violence                       440
# 2    CA   Nutrition, Physical Activity, & Obesity   377
# 3    CA   Infectious Disease                        319
# 4    CA   Cancer                                    314
# 5    CA   Maternal and Child Health                 281
# 6    TX   HIV/AIDS                                  237
# 7    TX   Injury and Violence                       189
# 8    CA   Food Safety                               186
# 9    TX   Cancer                                    164
# 10   CA   Life Expectancy and Death Rate (Overall)  154
# 11   TX   Infectious Disease                        154
# 12   TX   Nutrition, Physical Activity, & Obesity   149
# 13   CA   Behavioral Health/Substance Abuse         146
# 14   TX   Food Safety                               129
# 15   TX   Maternal and Child Health                 123
# ...
